# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [raw]
# Pandas - Panel Data Series

# %% [raw]
# Series - Always 1D
# Indexed - Index can be anything, It is not necessery to start with 0 and need to be integer

# %%
ls = ["January", "February", "March", "April"]

# %%
s1 = pd.Series(ls)
s1
# Out:
# 0     January
# 1    February
# 2       March
# 3       April
# dtype: object

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s1.values
# Out:
# array(['January', 'February', 'March', 'April'], dtype=object)

# %%
days = [31, 28, 31, 30]

# %%
s2 = pd.Series(days)

# %%
s2.index = ls

# %%
s2
# Out:
# January     31
# February    28
# March       31
# April       30
# dtype: int64

# %%
s2["January"]
# Out:
# 31

# %%
s2.mean()
# Out:
# 30.0

# %%
s2.std()
# Out:
# 1.4142135623730951

# %%
s2.sum()
# Out:
# 120

# %%
s2+3
# Out:
# January     34
# February    31
# March       34
# April       33
# dtype: int64

# %%
s2*3
# Out:
# January     93
# February    84
# March       93
# April       90
# dtype: int64

# %%
s2%5
# Out:
# January     1
# February    3
# March       1
# April       0
# dtype: int64

# %%
s2
# Out:
# January     31
# February    28
# March       31
# April       30
# dtype: int64

# %%
s2.values.tolist()
# Out:
# [31, 28, 31, 30]

# %%
s2.index.tolist()
# Out:
# ['January', 'February', 'March', 'April']

# %% [raw]
# DataFrame - Always 2D
#
# Dataframe - Integer, Float, Datetime, Object

# %%
days
# Out:
# [31, 28, 31, 30]

# %%
ls
# Out:
# ['January', 'February', 'March', 'April']

# %%
months = pd.DataFrame(np.array([days, ls]).T, columns=["Days", "Month"])

# %%
months
# Out:
#   Days     Month
# 0   31   January
# 1   28  February
# 2   31     March
# 3   30     April

# %%
np.array([days, ls]).T
# Out:
# array([['31', 'January'],
#        ['28', 'February'],
#        ['31', 'March'],
#        ['30', 'April']], dtype='<U11')

# %%
np.array([days, ls])
# Out:
# array([['31', '28', '31', '30'],
#        ['January', 'February', 'March', 'April']], dtype='<U11')

# %%
months["Year"] = [2024, 2023, 2034, 2022]

# %%
months
# Out:
#   Days     Month  Year
# 0   31   January  2024
# 1   28  February  2023
# 2   31     March  2034
# 3   30     April  2022

# %%
months2 = pd.DataFrame({"Days":days, "Month":ls})

# %%
months2
# Out:
#    Days     Month
# 0    31   January
# 1    28  February
# 2    31     March
# 3    30     April

# %%
demo = [{"Name":"Ram", "City":"Pune", "Contact":12345},
    {"Name":"Sham", "City":"Mumbai", "Contact":54321},
    {"Name":"Sita", "City":"Satara", "Contact":12543},
    {"Name":"Gita", "City":"Pune", "Contact":32145}]

# %%
demo
# Out:
# [{'Name': 'Ram', 'City': 'Pune', 'Contact': 12345},
#  {'Name': 'Sham', 'City': 'Mumbai', 'Contact': 54321},
#  {'Name': 'Sita', 'City': 'Satara', 'Contact': 12543},
#  {'Name': 'Gita', 'City': 'Pune', 'Contact': 32145}]

# %%
data = pd.DataFrame(demo)

# %%
data
# Out:
#    Name    City  Contact
# 0   Ram    Pune    12345
# 1  Sham  Mumbai    54321
# 2  Sita  Satara    12543
# 3  Gita    Pune    32145

# %%
df = pd.read_json("demo.json")

# %%
df
# Out:
#                                                    glossary
# title                                      example glossary
# GlossDiv  {'title': 'S', 'GlossList': {'GlossEntry': {'I...

# %%
df = pd.read_xml("demo.xml")

# %%
df
# Out:
#        id                author                                   title  \
# 0   bk101  Gambardella, Matthew                   XML Developer's Guide
# 1   bk102            Ralls, Kim                           Midnight Rain
# 2   bk103           Corets, Eva                         Maeve Ascendant
# 3   bk104           Corets, Eva                         Oberon's Legacy
# 4   bk105           Corets, Eva                      The Sundered Grail
# 5   bk106      Randall, Cynthia                             Lover Birds
# 6   bk107        Thurman, Paula                           Splish Splash
# 7   bk108         Knorr, Stefan                         Creepy Crawlies
# 8   bk109          Kress, Peter                            Paradox Lost
# 9   bk110          O'Brien, Tim   Microsoft .NET: The Programming Bible
# 10  bk111          O'Brien, Tim           MSXML3: A Comprehensive Guide
# 11  bk112           Galos, Mike  Visual Studio 7: A Comprehensive Guide
#
# ...

# %%
import mysql.connector as connector

# %%
try:
    conn = connector.connect(host="localhost", user="root", password="root")
    if conn:
        print("Connected")
        cursor = conn.cursor()
except:
    print("Not Connected")
# Out:
# Connected

# %%
pd.read_sql("Show databases;", conn)
# Out:
#              Database
# 0       classicmodels
# 1  information_schema
# 2          my_records
# 3               mysql
# 4  performance_schema
# 5              sakila
# 6           soccer_db
# 7                 sys
# 8               world

# %%
cursor.execute("use sakila;")

# %%
tables = pd.read_sql("Show tables;", conn)

# %%
pd.read_sql("Select * from customer", conn)
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       MARY      SMITH
# 1              2         1   PATRICIA    JOHNSON
# 2              3         1      LINDA   WILLIAMS
# 3              4         2    BARBARA      JONES
# 4              5         1  ELIZABETH      BROWN
# ..           ...       ...        ...        ...
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  active  \
# 0            MARY.SMITH@sakilacustomer.org           5       1
# 1      PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 2        LINDA.WILLIAMS@sakilacustomer.org           7       1
# 3         BARBARA.JONES@sakilacustomer.org           8       1
# ...

# %%
pd.read_html("demo.html")
# Out:
# [                      Company          Contact  Country
#  0         Alfreds Futterkiste     Maria Anders  Germany
#  1  Centro comercial Moctezuma  Francisco Chang   Mexico]

# %%
tables
# Out:
#               Tables_in_sakila
# 0                        actor
# 1                   actor_info
# 2                      address
# 3                     category
# 4                         city
# 5                      country
# 6                     customer
# 7                customer_list
# 8                         film
# 9                   film_actor
# 10               film_category
# 11                   film_list
# 12                   film_text
# 13                   inventory
# 14                    language
# 15  nicer_but_slower_film_list
# 16                     payment
# 17                      rental
# 18      sales_by_film_category
# 19              sales_by_store
# 20                       staff
# 21                  staff_list
# 22                       store

# %%
payment = pd.read_sql("Select * from payment", conn)

# %%
payment
# Out:
#        payment_id  customer_id  staff_id  rental_id  amount  \
# 0               1            1         1         76    2.99
# 1               2            1         1        573    0.99
# 2               3            1         1       1185    5.99
# 3               4            1         2       1422    0.99
# 4               5            1         2       1476    9.99
# ...           ...          ...       ...        ...     ...
# 16039       16045          599         1      14599    4.99
# 16040       16046          599         1      14719    1.99
# 16041       16047          599         2      15590    8.99
# 16042       16048          599         2      15719    2.99
# 16043       16049          599         2      15725    2.99
#
#              payment_date         last_update
# 0     2005-05-25 11:30:37 2006-02-15 22:12:30
# 1     2005-05-28 10:35:23 2006-02-15 22:12:30
# 2     2005-06-15 00:54:12 2006-02-15 22:12:30
# 3     2005-06-15 18:02:53 2006-02-15 22:12:30
# ...

# %%
payment.groupby("customer_id")["amount"].sum()
# Out:
# customer_id
# 1      118.68
# 2      128.73
# 3      135.74
# 4       81.78
# 5      144.62
#         ...
# 595    117.70
# 596     96.72
# 597     99.75
# 598     83.78
# 599     83.81
# Name: amount, Length: 599, dtype: float64

# %%
df = pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\SampleSuperstore.xlsx",
                  sheet_name="Orders")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky      42420.0
# 1      Claire Gute   Consumer        Henderson    Kentucky      42420.0
# 2  Darrin Van Huff  Corporate      Los Angeles  California      90036.0
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida      33311.0
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida      33311.0
#
#   Region       Product ID         Category Sub-Category  \
# ...

# %%
df.drop(columns=["Row ID", "Customer ID", "Product ID", "Order ID"], inplace=True)

# %%
df.head()
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 1 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 2 2017-06-12 2017-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
# 4 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky      42420.0  South        Furniture
# 1        Henderson    Kentucky      42420.0  South        Furniture
# 2      Los Angeles  California      90036.0   West  Office Supplies
# 3  Fort Lauderdale     Florida      33311.0  South        Furniture
# 4  Fort Lauderdale     Florida      33311.0  South  Office Supplies
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Date     9994 non-null   datetime64[ns]
#  1   Ship Date      9994 non-null   datetime64[ns]
#  2   Ship Mode      9994 non-null   object
#  3   Customer Name  9994 non-null   object
#  4   Segment        9994 non-null   object
#  5   City           9994 non-null   object
#  6   State          9994 non-null   object
#  7   Postal Code    9983 non-null   float64
#  8   Region         9994 non-null   object
#  9   Category       9994 non-null   object
#  10  Sub-Category   9994 non-null   object
#  11  Product Name   9994 non-null   object
#  12  Sales          9994 non-null   float64
#  13  Quantity       9994 non-null   int64
#  14  Discount       9994 non-null   float64
#  15  Profit         9994 non-null   float64
# ...

# %%
df.iloc[:10]
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 1 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 2 2017-06-12 2017-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
# 4 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
# 5 2015-06-09 2015-06-14  Standard Class  Brosina Hoffman   Consumer
# 6 2015-06-09 2015-06-14  Standard Class  Brosina Hoffman   Consumer
# 7 2015-06-09 2015-06-14  Standard Class  Brosina Hoffman   Consumer
# 8 2015-06-09 2015-06-14  Standard Class  Brosina Hoffman   Consumer
# 9 2015-06-09 2015-06-14  Standard Class  Brosina Hoffman   Consumer
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky      42420.0  South        Furniture
# 1        Henderson    Kentucky      42420.0  South        Furniture
# ...

# %%
df.iloc[100:120]
# Out:
#     Order Date  Ship Date       Ship Mode      Customer Name      Segment  \
# 100 2017-08-29 2017-09-02  Standard Class       Rick Bensley  Home Office
# 101 2017-08-29 2017-09-02  Standard Class       Rick Bensley  Home Office
# 102 2017-12-01 2017-12-04    Second Class      Gary Zandusky     Consumer
# 103 2016-11-13 2016-11-17  Standard Class      Lena Cacioppo     Consumer
# 104 2016-11-13 2016-11-17  Standard Class      Lena Cacioppo     Consumer
# 105 2016-11-13 2016-11-17  Standard Class      Lena Cacioppo     Consumer
# 106 2018-11-23 2018-11-28  Standard Class       Janet Martin     Consumer
# 107 2018-11-23 2018-11-28  Standard Class       Janet Martin     Consumer
# 108 2018-11-23 2018-11-28  Standard Class       Janet Martin     Consumer
# 109 2016-10-15 2016-10-20  Standard Class     Pete Armstrong  Home Office
# 110 2018-12-25 2018-12-30  Standard Class      Cynthia Voltz    Corporate
# 111 2017-11-03 2017-11-10  Standard Class        Clay Ludtke     Consumer
# ...

# %%
df.isna().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.iloc[np.random.choice(df.index, 5)]
# Out:
#      Order Date  Ship Date       Ship Mode      Customer Name      Segment  \
# 3966 2017-05-20 2017-05-23     First Class  Eugene Hildebrand  Home Office
# 2124 2018-12-01 2018-12-05  Standard Class    Erica Hernandez  Home Office
# 9544 2016-11-28 2016-12-02  Standard Class     Eugene Barchas     Consumer
# 7099 2017-08-01 2017-08-05    Second Class     Susan Gilcrest    Corporate
# 2063 2015-10-31 2015-11-04  Standard Class       Greg Guthrie    Corporate
#
#                   City         State  Postal Code   Region         Category  \
# 3966  Colorado Springs      Colorado      80906.0     West  Office Supplies
# 2124      Philadelphia  Pennsylvania      19143.0     East  Office Supplies
# 9544          Columbus          Ohio      43229.0     East        Furniture
# 7099          Amarillo         Texas      79109.0  Central  Office Supplies
# 2063       Los Angeles    California      90049.0     West  Office Supplies
#
# ...

# %%
np.random.choice(df.index, 5)
# Out:
# array([3799, 8795, 6769, 4762, 7431], dtype=int64)

# %%
df.iloc[[3799, 8795, 6769, 4762, 7431]]
# Out:
#      Order Date  Ship Date       Ship Mode  Customer Name    Segment  \
# 3799 2017-10-14 2017-10-20  Standard Class    Nathan Cano   Consumer
# 8795 2017-07-07 2017-07-13  Standard Class      Max Jones   Consumer
# 6769 2018-12-09 2018-12-13  Standard Class  Nick Crebassa  Corporate
# 4762 2015-09-17 2015-09-21  Standard Class   Nick Radford   Consumer
# 7431 2015-08-09 2015-08-13  Standard Class    Roger Demir   Consumer
#
#               City           State  Postal Code Region         Category  \
# 3799  Jacksonville  North Carolina      28540.0  South        Furniture
# 8795          Orem            Utah      84057.0   West  Office Supplies
# 6769       Phoenix         Arizona      85023.0   West  Office Supplies
# 4762   Chula Vista      California      91911.0   West  Office Supplies
# 7431       Phoenix         Arizona      85023.0   West  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# ...

# %%
df[["Ship Mode", "Sales", "Profit"]]
# Out:
#            Ship Mode     Sales    Profit
# 0       Second Class  261.9600   41.9136
# 1       Second Class  731.9400  219.5820
# 2       Second Class   14.6200    6.8714
# 3     Standard Class  957.5775 -383.0310
# 4     Standard Class   22.3680    2.5164
# ...              ...       ...       ...
# 9978    Second Class   25.2480    4.1028
# 9979  Standard Class   91.9600   15.6332
# 9980  Standard Class  258.5760   19.3932
# 9981  Standard Class   29.6000   13.3200
# 9982    Second Class  243.1600   72.9480
#
# [9983 rows x 3 columns]

# %%
df.loc[:, "Ship Mode":"Region"]
# Out:
#            Ship Mode     Customer Name    Segment             City  \
# 0       Second Class       Claire Gute   Consumer        Henderson
# 1       Second Class       Claire Gute   Consumer        Henderson
# 2       Second Class   Darrin Van Huff  Corporate      Los Angeles
# 3     Standard Class    Sean O'Donnell   Consumer  Fort Lauderdale
# 4     Standard Class    Sean O'Donnell   Consumer  Fort Lauderdale
# ...              ...               ...        ...              ...
# 9978    Second Class  Tom Boeckenhauer   Consumer            Miami
# 9979  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9980  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9981  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9982    Second Class      Chris Cortes   Consumer      Westminster
#
#            State  Postal Code Region
# 0       Kentucky      42420.0  South
# 1       Kentucky      42420.0  South
# 2     California      90036.0   West
# ...

# %%
df.iloc[:, 2:8]
# Out:
#            Ship Mode     Customer Name    Segment             City  \
# 0       Second Class       Claire Gute   Consumer        Henderson
# 1       Second Class       Claire Gute   Consumer        Henderson
# 2       Second Class   Darrin Van Huff  Corporate      Los Angeles
# 3     Standard Class    Sean O'Donnell   Consumer  Fort Lauderdale
# 4     Standard Class    Sean O'Donnell   Consumer  Fort Lauderdale
# ...              ...               ...        ...              ...
# 9978    Second Class  Tom Boeckenhauer   Consumer            Miami
# 9979  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9980  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9981  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9982    Second Class      Chris Cortes   Consumer      Westminster
#
#            State  Postal Code
# 0       Kentucky      42420.0
# 1       Kentucky      42420.0
# 2     California      90036.0
# 3        Florida      33311.0
# ...

# %%
df.loc[:, "Ship Mode":"Region"]
# Out:
#            Ship Mode     Customer Name    Segment             City  \
# 0       Second Class       Claire Gute   Consumer        Henderson
# 1       Second Class       Claire Gute   Consumer        Henderson
# 2       Second Class   Darrin Van Huff  Corporate      Los Angeles
# 3     Standard Class    Sean O'Donnell   Consumer  Fort Lauderdale
# 4     Standard Class    Sean O'Donnell   Consumer  Fort Lauderdale
# ...              ...               ...        ...              ...
# 9978    Second Class  Tom Boeckenhauer   Consumer            Miami
# 9979  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9980  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9981  Standard Class       Dave Brooks   Consumer       Costa Mesa
# 9982    Second Class      Chris Cortes   Consumer      Westminster
#
#            State  Postal Code Region
# 0       Kentucky      42420.0  South
# 1       Kentucky      42420.0  South
# 2     California      90036.0   West
# ...

# %%
df[(df["Ship Mode"]=="Second Class")&(df["Segment"]=="Consumer")&(df["State"]=="Florida")]
# Out:
#      Order Date  Ship Date     Ship Mode        Customer Name   Segment  \
# 561  2015-09-14 2015-09-18  Second Class      Cynthia Arntzen  Consumer
# 562  2015-09-14 2015-09-18  Second Class      Cynthia Arntzen  Consumer
# 633  2018-09-24 2018-09-26  Second Class         Brian Dahlen  Consumer
# 634  2018-09-24 2018-09-26  Second Class         Brian Dahlen  Consumer
# 963  2015-09-22 2015-09-24  Second Class  Maribeth Schnelling  Consumer
# 1892 2018-12-22 2018-12-24  Second Class        Jeremy Pistek  Consumer
# 1897 2015-08-29 2015-09-02  Second Class            Ryan Akin  Consumer
# 1898 2015-08-29 2015-09-02  Second Class            Ryan Akin  Consumer
# 1899 2015-08-29 2015-09-02  Second Class            Ryan Akin  Consumer
# 3463 2018-12-03 2018-12-05  Second Class    Natalie DeCherney  Consumer
# 3772 2015-04-11 2015-04-13  Second Class           Jay Kimmel  Consumer
# 3773 2015-04-11 2015-04-13  Second Class           Jay Kimmel  Consumer
# ...

# %%
df[(df["Ship Mode"]=="Second Class")&(df["Segment"]=="Consumer")&(df["State"]=="Florida")]["Sales"].sum()
# Out:
# 7858.7065

# %%
df[(df["Sales"]>=1000)&(df["Sales"]<=2000)]
# Out:
#      Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 10   2015-06-09 2015-06-14  Standard Class  Brosina Hoffman   Consumer
# 24   2016-09-25 2016-09-30  Standard Class      Emily Burns   Consumer
# 35   2017-12-08 2017-12-10     First Class        Gene Hale  Corporate
# 54   2017-12-11 2017-12-17  Standard Class   Janet Molinari  Corporate
# 67   2015-12-05 2015-12-10  Standard Class    Brendan Sweed  Corporate
# ...         ...        ...             ...              ...        ...
# 9748 2017-10-31 2017-11-05  Standard Class  Sylvia Foulston  Corporate
# 9776 2018-03-27 2018-04-01  Standard Class  Caroline Jumper   Consumer
# 9855 2016-03-26 2016-03-28    Second Class   Suzanne McNair  Corporate
# 9914 2016-03-20 2016-03-23     First Class    Dave Hallsten  Corporate
# 9936 2018-06-01 2018-06-03    Second Class  Helen Wasserman  Corporate
#
#                City       State  Postal Code   Region         Category  \
# ...

# %% [raw]
# Data Analysis
# * Indexing and Slicing
# * Filtering
# * Groupby
# * Pivote Table
# * Correlation
# * Crosstab
# * Cut
# * Sorting of Index and Values

# %%
round(df.groupby("Ship Mode")["Sales"].sum())
# Out:
# Ship Mode
# First Class        351428.0
# Same Day           128363.0
# Second Class       458478.0
# Standard Class    1350002.0
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%.2f")
# Out:
# <Axes: ylabel='Sales'>

# %%
pd.pivot_table(df, columns="Region", index="Segment", values="Sales", aggfunc="sum")
# Out:
# Region           Central        East        South         West
# Segment
# Consumer     252031.4340  349555.787  195580.9710  362880.7730
# Corporate    157995.8128  194127.107  121885.9325  225855.2745
# Home Office   91212.6440  126168.976   74255.0015  136721.7770

# %%
pd.pivot_table(df, columns="Region", index="Segment", values="Sales").plot.bar(cmap="viridis")
# Out:
# <Axes: xlabel='Segment'>

# %%
pd.pivot_table(df, index="State", columns="Category", values="Sales", aggfunc="sum")
# Out:
# Category                Furniture  Office Supplies  Technology
# State
# Alabama                 6332.4800         4209.080    8969.080
# Arizona                13525.2910        10005.825   11750.885
# Arkansas                3187.5500         4565.330    3925.250
# California            156064.6015       142351.948  159271.082
# Colorado               13243.0370         7898.752   10966.329
# Connecticut             5174.9870         5418.340    2791.030
# Delaware                4759.3190         8129.530   14562.220
# District of Columbia    1346.5800          138.520    1379.920
# Florida                22987.0380        19518.634   46968.036
# Georgia                 8321.4800        26715.810   14058.550
# Idaho                   2595.4820          949.506     837.498
# Illinois               28274.5220        19907.906   31983.673
# Indiana                11496.7100        15735.400   26323.250
# Iowa                    2642.3100          783.150    1154.300
# ...

# %%
pd.pivot_table(df, index="State", columns="Category", values="Sales", aggfunc="sum").plot.bar(figsize=(15,5),legend=False)
# Out:
# <Axes: xlabel='State'>

# %%
df.head()
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 1 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 2 2017-06-12 2017-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
# 4 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky      42420.0  South        Furniture
# 1        Henderson    Kentucky      42420.0  South        Furniture
# 2      Los Angeles  California      90036.0   West  Office Supplies
# 3  Fort Lauderdale     Florida      33311.0  South        Furniture
# 4  Fort Lauderdale     Florida      33311.0  South  Office Supplies
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
(df["Profit"]/df["Sales"])*100
# Out:
# 0       16.00
# 1       30.00
# 2       47.00
# 3      -40.00
# 4       11.25
#         ...
# 9978    16.25
# 9979    17.00
# 9980     7.50
# 9981    45.00
# 9982    30.00
# Length: 9983, dtype: float64

# %%
user=pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\BhaiBhaiCo-Ops.xlsx", sheet_name="User")
loan=pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\BhaiBhaiCo-Ops.xlsx", sheet_name="Loans")
car=pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\BhaiBhaiCo-Ops.xlsx", sheet_name="Car")
bike=pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\BhaiBhaiCo-Ops.xlsx", sheet_name="Bike")
home=pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\BhaiBhaiCo-Ops.xlsx", sheet_name="Home")
default=pd.read_excel(r"C:\Users\Soft\Desktop\Py\Docs\BhaiBhaiCo-Ops.xlsx", sheet_name="Default")

# %%
user
# Out:
#    UID    Name
# 0    1     Ram
# 1    2    Sham
# 2    3    Sita
# 3    4    Gita
# 4    5    Hema
# 5    6   Rekha
# 6    7    Jaya
# 7    8  Sushma
# 8    9   Rocky
# 9   10   Rinki

# %%
loan
# Out:
#     UserID  LoanID
# 0        1     101
# 1        1     301
# 2        2     102
# 3        2     201
# 4        2     302
# 5        3     202
# 6        3     303
# 7        4     103
# 8        4     203
# 9        5     104
# 10       5     204
# 11       5     304
# 12       6     305
# 13       7     105
# 14       7     205
# 15       8     106
# 16       8     206
# 17       8     306
# 18       9     207
# 19       9     307
# 20      10     107

# %%
car
# Out:
#    Loan ID  Amount
# 0      101    2800
# 1      102    2700
# 2      103    2700
# 3      104    2500
# 4      105    2700
# 5      106    2900
# 6      107    2300

# %%
bike
# Out:
#    Loan ID  Amount
# 0      201    1700
# 1      202    1100
# 2      203    1100
# 3      204    1100
# 4      205    1700
# 5      206    1600
# 6      207    1100

# %%
home
# Out:
#    Loan ID  Amount
# 0      301    4400
# 1      302    4900
# 2      303    4200
# 3      304    4600
# 4      305    4800
# 5      306    4300
# 6      307    4200

# %%
default
# Out:
#    UID  DefaultAmt
# 0    2        1200
# 1    5         650
# 2    8         980
# 3    4        1130

# %%
loan.columns="UID","Loan ID"

# %%
loan
# Out:
#     UID  Loan ID
# 0     1      101
# 1     1      301
# 2     2      102
# 3     2      201
# 4     2      302
# 5     3      202
# 6     3      303
# 7     4      103
# 8     4      203
# 9     5      104
# 10    5      204
# 11    5      304
# 12    6      305
# 13    7      105
# 14    7      205
# 15    8      106
# 16    8      206
# 17    8      306
# 18    9      207
# 19    9      307
# 20   10      107

# %%
user_loan = user.join(loan, lsuffix="_")

# %%
user_loan
# Out:
#    UID_    Name  UID  Loan ID
# 0     1     Ram    1      101
# 1     2    Sham    1      301
# 2     3    Sita    2      102
# 3     4    Gita    2      201
# 4     5    Hema    2      302
# 5     6   Rekha    3      202
# 6     7    Jaya    3      303
# 7     8  Sushma    4      103
# 8     9   Rocky    4      203
# 9    10   Rinki    5      104

# %%
user_loan = user.merge(loan, on="UID")

# %%
user_loan
# Out:
#     UID    Name  Loan ID
# 0     1     Ram      101
# 1     1     Ram      301
# 2     2    Sham      102
# 3     2    Sham      201
# 4     2    Sham      302
# 5     3    Sita      202
# 6     3    Sita      303
# 7     4    Gita      103
# 8     4    Gita      203
# 9     5    Hema      104
# 10    5    Hema      204
# 11    5    Hema      304
# 12    6   Rekha      305
# 13    7    Jaya      105
# 14    7    Jaya      205
# 15    8  Sushma      106
# 16    8  Sushma      206
# 17    8  Sushma      306
# 18    9   Rocky      207
# 19    9   Rocky      307
# 20   10   Rinki      107

# %%
bike_loan = user_loan.merge(bike, on="Loan ID")
bike_loan
# Out:
#    UID    Name  Loan ID  Amount
# 0    2    Sham      201    1700
# 1    3    Sita      202    1100
# 2    4    Gita      203    1100
# 3    5    Hema      204    1100
# 4    7    Jaya      205    1700
# 5    8  Sushma      206    1600
# 6    9   Rocky      207    1100

# %%
car_loan = user_loan.merge(car, on="Loan ID", how="inner")
car_loan
# Out:
#    UID    Name  Loan ID  Amount
# 0    1     Ram      101    2800
# 1    2    Sham      102    2700
# 2    4    Gita      103    2700
# 3    5    Hema      104    2500
# 4    7    Jaya      105    2700
# 5    8  Sushma      106    2900
# 6   10   Rinki      107    2300

# %%
user.merge(default, on="UID", how="inner")
# Out:
#    UID    Name  DefaultAmt
# 0    2    Sham        1200
# 1    4    Gita        1130
# 2    5    Hema         650
# 3    8  Sushma         980

# %%
home_loan = user_loan.merge(home, on="Loan ID")

# %%
home_loan
# Out:
#    UID    Name  Loan ID  Amount
# 0    1     Ram      301    4400
# 1    2    Sham      302    4900
# 2    3    Sita      303    4200
# 3    5    Hema      304    4600
# 4    6   Rekha      305    4800
# 5    8  Sushma      306    4300
# 6    9   Rocky      307    4200

# %%
pd.concat([bike_loan, car_loan, home_loan], axis=0)
# Out:
#    UID    Name  Loan ID  Amount
# 0    2    Sham      201    1700
# 1    3    Sita      202    1100
# 2    4    Gita      203    1100
# 3    5    Hema      204    1100
# 4    7    Jaya      205    1700
# 5    8  Sushma      206    1600
# 6    9   Rocky      207    1100
# 0    1     Ram      101    2800
# 1    2    Sham      102    2700
# 2    4    Gita      103    2700
# 3    5    Hema      104    2500
# 4    7    Jaya      105    2700
# 5    8  Sushma      106    2900
# 6   10   Rinki      107    2300
# 0    1     Ram      301    4400
# 1    2    Sham      302    4900
# 2    3    Sita      303    4200
# 3    5    Hema      304    4600
# 4    6   Rekha      305    4800
# 5    8  Sushma      306    4300
# 6    9   Rocky      307    4200

# %%
df.head()
# Out:
#   Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 0 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 1 2017-11-08 2017-11-11    Second Class      Claire Gute   Consumer
# 2 2017-06-12 2017-06-16    Second Class  Darrin Van Huff  Corporate
# 3 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
# 4 2016-10-11 2016-10-18  Standard Class   Sean O'Donnell   Consumer
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky      42420.0  South        Furniture
# 1        Henderson    Kentucky      42420.0  South        Furniture
# 2      Los Angeles  California      90036.0   West  Office Supplies
# 3  Fort Lauderdale     Florida      33311.0  South        Furniture
# 4  Fort Lauderdale     Florida      33311.0  South  Office Supplies
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
pd.crosstab(df["Segment"], df["Ship Mode"])
# Out:
# Ship Mode    First Class  Same Day  Second Class  Standard Class
# Segment
# Consumer             769       317          1019            3081
# Corporate            485       114           609            1807
# Home Office          284       112           316            1070

# %%
pd.crosstab(df["Category"], df["Region"]).plot.barh()
# Out:
# <Axes: ylabel='Category'>

# %%
pd.cut(df["Sales"], bins=10)
# Out:
# 0       (-22.194, 2264.248]
# 1       (-22.194, 2264.248]
# 2       (-22.194, 2264.248]
# 3       (-22.194, 2264.248]
# 4       (-22.194, 2264.248]
#                ...
# 9978    (-22.194, 2264.248]
# 9979    (-22.194, 2264.248]
# 9980    (-22.194, 2264.248]
# 9981    (-22.194, 2264.248]
# 9982    (-22.194, 2264.248]
# Name: Sales, Length: 9983, dtype: category
# Categories (10, interval[float64, right]): [(-22.194, 2264.248] < (2264.248, 4528.051] < (4528.051, 6791.855] < (6791.855, 9055.658] ... (13583.266, 15847.069] < (15847.069, 18110.873] < (18110.873, 20374.676] < (20374.676, 22638.48]]

# %%
df["Quantity"]
# Out:
# 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9978    3
# 9979    2
# 9980    2
# 9981    4
# 9982    2
# Name: Quantity, Length: 9983, dtype: int64

# %%
df["Quantity"].value_counts()
# Out:
# Quantity
# 3     2407
# 2     2401
# 5     1228
# 4     1190
# 1      897
# 7      605
# 6      571
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      26
# 12      23
# Name: count, dtype: int64

# %%
pd.cut(df["Quantity"], bins=[1, 5, 9, 14], include_lowest=True)
# Out:
# 0       (0.999, 5.0]
# 1       (0.999, 5.0]
# 2       (0.999, 5.0]
# 3       (0.999, 5.0]
# 4       (0.999, 5.0]
#             ...
# 9978    (0.999, 5.0]
# 9979    (0.999, 5.0]
# 9980    (0.999, 5.0]
# 9981    (0.999, 5.0]
# 9982    (0.999, 5.0]
# Name: Quantity, Length: 9983, dtype: category
# Categories (3, interval[float64, right]): [(0.999, 5.0] < (5.0, 9.0] < (9.0, 14.0]]
